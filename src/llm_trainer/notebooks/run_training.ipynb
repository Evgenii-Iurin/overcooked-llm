# %%
# %%bash
# git clone https://github.com/Evgenii-Iurin/overcooked-llm.git
# pip -q install -U poetry
# cd overcooked-llm/
#
# poetry run python - <<'PY' 2>&1 | tee run.log
# from llm_trainer.train_grpo import train_grpo_overcooked
#
# if __name__ == "__main__":
#     train_grpo_overcooked(
#         model_name="Qwen/Qwen2.5-0.5B-Instruct",
#         env_name="overcooked_v2",
#         env_kwargs={"layout": "cramped_room", "max_steps": 400},
#         num_episodes_per_iteration=10,
#         num_iterations=100,
#         output_dir="outputs/overcooked_grpo",
#         use_vllm=False,
#     )
# PY
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 281.6/281.6 kB 10.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 338.6/338.6 kB 22.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 9.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 63.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.8/453.8 kB 43.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 142.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 47.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 121.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.20.0
#     Uninstalling filelock-3.20.0:
#       Successfully uninstalled filelock-3.20.0
# ...
# Poetry could not find a pyproject.toml file in /content or its parents
# ...
